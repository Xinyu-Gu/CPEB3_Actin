# %%
import matplotlib.pyplot as plt
import numpy as np

go_AA=np.loadtxt('go_rnativeCACA.dat')
N=len(go_AA)
M=159

# %%
plt.figure(figsize=(40,40))
plt.imshow(go_AA)

# %%
sigma=go_AA[N-M:,...]
plt.figure(figsize=(60,10))
plt.imshow(sigma)
plt.savefig("go_AA.png")

# %%
sigma=go_AA[N-M:,750:1875]
plt.figure(figsize=(40,10))
plt.imshow(sigma)
plt.savefig("go_AA-345-p.png")
